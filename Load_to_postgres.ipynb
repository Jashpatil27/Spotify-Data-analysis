# %%
# !pip install psycopg2-binary sqlalchemy pandas
# Out:
# Requirement already satisfied: psycopg2-binary in c:\users\jash patil\appdata\local\programs\python\python312\lib\site-packages (2.9.12)
# Requirement already satisfied: sqlalchemy in c:\users\jash patil\appdata\local\programs\python\python312\lib\site-packages (2.0.38)
# Requirement already satisfied: pandas in c:\users\jash patil\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\jash patil\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\jash patil\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy) (4.12.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\jash patil\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jash patil\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jash patil\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jash patil\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\jash patil\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\jash patil\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\jash patil\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\jash patil\AppData\Local\Programs\Python\Python312\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

df = pd.read_csv('spotify_cleaned.csv')
df.head()
# Out:
#                  ts                                     platform  ms_played  \
# 0  24-08-2020 21:45  Android OS 5.1.1 API 22 (samsung, SM-J500F)       5061
# 1  25-08-2020 13:22  Android OS 5.1.1 API 22 (samsung, SM-J500F)       1533
# 2  25-08-2020 18:10  Android OS 5.1.1 API 22 (samsung, SM-J500F)     152578
# 3  25-08-2020 18:13  Android OS 5.1.1 API 22 (samsung, SM-J500F)     174654
# 4  25-08-2020 18:16  Android OS 5.1.1 API 22 (samsung, SM-J500F)     142928
#
#   conn_country master_metadata_track_name master_metadata_album_artist_name  \
# 0           IN                 Astronomia                          Vicetone
# 1           IN            One Thing Right                        Marshmello
# 2           IN                   Believer                   Imagine Dragons
# 3           IN                    Thunder                   Imagine Dragons
# 4           IN            Yaarr Ni Milyaa                     Harrdy Sandhu
#
#   master_metadata_album_album_name                     spotify_track_uri  \
# 0                       Astronomia  spotify:track:3hWfKBt3n7j1xqIy6LA5ve
# 1                  One Thing Right  spotify:track:4hPpVbbakQNv8YTHYaOJP4
# 2                           Evolve  spotify:track:0pqnGHJpmpxLKifKRmU6WP
# 3                           Evolve  spotify:track:1zB4vmk8tFRmM9UULNzbLB
# 4                  Yaarr Ni Milyaa  spotify:track:6N4TjPeZi4S9jpayOpRX2h
#
#   reason_start reason_end  ...  is_real_listen          ts_local        date  \
# 0     clickrow    endplay  ...           False  25-08-2020 03:15  25-08-2020
# 1      playbtn     logout  ...           False  25-08-2020 18:52  25-08-2020
# 2     clickrow  trackdone  ...            True  25-08-2020 23:40  25-08-2020
# 3    trackdone    endplay  ...            True  25-08-2020 23:43  25-08-2020
# 4     clickrow    endplay  ...            True  25-08-2020 23:46  25-08-2020
#
#    year  month  month_name  day_of_week hour ms_played_min  content_type
# 0  2020      8         Aug      Tuesday    3      0.084350         music
# 1  2020      8         Aug      Tuesday   18      0.025550         music
# 2  2020      8         Aug      Tuesday   23      2.542967         music
# 3  2020      8         Aug      Tuesday   23      2.910900         music
# 4  2020      8         Aug      Tuesday   23      2.382133         music
#
# [5 rows x 26 columns]

# %%
from sqlalchemy import create_engine
from sqlalchemy.engine import URL

url = URL.create(
    drivername='postgresql',
    username='postgres',
    password='Jash_tanish@2004',   # your real password here
    host='localhost',
    port=5432,
    database='Spotify_data'
)

engine = create_engine(url)

df.to_sql('plays', engine, if_exists='replace', index=False)
print("Done. Rows loaded:", len(df))
# Out:
# Done. Rows loaded: 48514
